# %%
import torch
import numpy as np
from scipy.ndimage.filters import median_filter, gaussian_filter
from scipy.signal import convolve2d, correlate2d
from skimage.util import random_noise
import os
import shutil
# Out:
# /tmp/ipykernel_36455/416237552.py:3: DeprecationWarning: Please import `median_filter` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import median_filter, gaussian_filter
# /tmp/ipykernel_36455/416237552.py:3: DeprecationWarning: Please import `gaussian_filter` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import median_filter, gaussian_filter

# %%
class Example:
    def __init__(self, full_identifier, label):
        self.full_identifier = full_identifier
        self.label = label

    def __repr__(self):
        return (f"Example(full_identifier='{self.full_identifier}', label={self.label})")

def parse_file(file_path):
    objects = []
    with open(file_path, 'r') as file:
        for line in file:
            # Split the line
            parts = line.strip().split()
            full_identifier = parts[0]  # Keep the full identifier (e.g., 'american_bulldog_125')
            label = list(map(int, parts[1:]))  # Convert the label parts into a list of integers
            objects.append(Example(full_identifier, label))
    return objects


# Example usage
trainval_txt_path = '../annotations/trainval.txt'
test_txt_path = '../annotations/test.txt'

trainval_txt = parse_file(trainval_txt_path)
test_txt = parse_file(test_txt_path)

print(trainval_txt[100])
# Out:
# Example(full_identifier='american_pit_bull_terrier_100', label=[3, 2, 2])

# %%
def copy_matching_pictures(examples, source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)  # Create the destination folder if it doesn't exist

    for example in examples:
        picture_name = f"{example.full_identifier}.jpg"  # Construct the expected picture file name
        source_path = os.path.join(source_folder, picture_name)
        destination_path = os.path.join(destination_folder, picture_name)
        
        if os.path.exists(source_path):
            shutil.copy(source_path, destination_path)  # Copy the file to the destination folder
            print(f"Copied: {picture_name} to {destination_folder}")
        else:
            print(f"File not found: {source_path}")

source_folder = '../images'  # Replace with the folder containing pictures

destination_folder = '../training_val'  # Replace with the folder to store matching pictures
copy_matching_pictures(trainval_txt, source_folder, destination_folder)

destination_folder = '../test'  # Replace with the folder to store matching pictures
copy_matching_pictures(test_txt, source_folder, destination_folder)
# Out:
# Copied: Abyssinian_100.jpg to ../training_val
# Copied: Abyssinian_101.jpg to ../training_val
# Copied: Abyssinian_102.jpg to ../training_val
# Copied: Abyssinian_103.jpg to ../training_val
# Copied: Abyssinian_104.jpg to ../training_val
# Copied: Abyssinian_105.jpg to ../training_val
# Copied: Abyssinian_106.jpg to ../training_val
# Copied: Abyssinian_107.jpg to ../training_val
# Copied: Abyssinian_108.jpg to ../training_val
# Copied: Abyssinian_109.jpg to ../training_val
# Copied: Abyssinian_10.jpg to ../training_val
# Copied: Abyssinian_110.jpg to ../training_val
# Copied: Abyssinian_111.jpg to ../training_val
# Copied: Abyssinian_112.jpg to ../training_val
# Copied: Abyssinian_113.jpg to ../training_val
# Copied: Abyssinian_114.jpg to ../training_val
# Copied: Abyssinian_115.jpg to ../training_val
# Copied: Abyssinian_116.jpg to ../training_val
# Copied: Abyssinian_117.jpg to ../training_val
# Copied: Abyssinian_118.jpg to ../training_val
# Copied: Abyssinian_119.jpg to ../training_val
# Copied: Abyssinian_11.jpg to ../training_val
# Copied: Abyssinian_120.jpg to ../training_val
# Copied: Abyssinian_121.jpg to ../training_val
# Copied: Abyssinian_122.jpg to ../training_val
# Copied: Abyssinian_123.jpg to ../training_val
# Copied: Abyssinian_124.jpg to ../training_val
# Copied: Abyssinian_125.jpg to ../training_val
# Copied: Abyssinian_126.jpg to ../training_val
# Copied: Abyssinian_127.jpg to ../training_val
# Copied: Abyssinian_128.jpg to ../training_val
# Copied: Abyssinian_129.jpg to ../training_val
# Copied: Abyssinian_12.jpg to ../training_val
# Copied: Abyssinian_130.jpg to ../training_val
# Copied: Abyssinian_131.jpg to ../training_val
# Copied: Abyssinian_132.jpg to ../training_val
# Copied: Abyssinian_133.jpg to ../training_val
# Copied: Abyssinian_134.jpg to ../training_val
# Copied: Abyssinian_135.jpg to ../training_val
# Copied: Abyssinian_136.jpg to ../training_val
# Copied: Abyssinian_137.jpg to ../training_val
# Copied: Abyssinian_138.jpg to ../training_val
# Copied: Abyssinian_139.jpg to ../training_val
# Copied: Abyssinian_13.jpg to ../training_val
# Copied: Abyssinian_140.jpg to ../training_val
# Copied: Abyssinian_141.jpg to ../training_val
# Copied: Abyssinian_142.jpg to ../training_val
# Copied: Abyssinian_143.jpg to ../training_val
# Copied: Abyssinian_144.jpg to ../training_val
# Copied: Abyssinian_145.jpg to ../training_val
# Copied: american_bulldog_100.jpg to ../training_val
# Copied: american_bulldog_101.jpg to ../training_val
# Copied: american_bulldog_102.jpg to ../training_val
# Copied: american_bulldog_103.jpg to ../training_val
# Copied: american_bulldog_104.jpg to ../training_val
# Copied: american_bulldog_105.jpg to ../training_val
# Copied: american_bulldog_106.jpg to ../training_val
# Copied: american_bulldog_107.jpg to ../training_val
# Copied: american_bulldog_108.jpg to ../training_val
# Copied: american_bulldog_109.jpg to ../training_val
# Copied: american_bulldog_10.jpg to ../training_val
# Copied: american_bulldog_110.jpg to ../training_val
# Copied: american_bulldog_111.jpg to ../training_val
# Copied: american_bulldog_112.jpg to ../training_val
# Copied: american_bulldog_113.jpg to ../training_val
# Copied: american_bulldog_114.jpg to ../training_val
# Copied: american_bulldog_115.jpg to ../training_val
# Copied: american_bulldog_116.jpg to ../training_val
# Copied: american_bulldog_117.jpg to ../training_val
# Copied: american_bulldog_118.jpg to ../training_val
# Copied: american_bulldog_119.jpg to ../training_val
# Copied: american_bulldog_11.jpg to ../training_val
# Copied: american_bulldog_120.jpg to ../training_val
# Copied: american_bulldog_121.jpg to ../training_val
# Copied: american_bulldog_122.jpg to ../training_val
# Copied: american_bulldog_123.jpg to ../training_val
# Copied: american_bulldog_124.jpg to ../training_val
# Copied: american_bulldog_125.jpg to ../training_val
# Copied: american_bulldog_126.jpg to ../training_val
# Copied: american_bulldog_127.jpg to ../training_val
# Copied: american_bulldog_128.jpg to ../training_val
# Copied: american_bulldog_129.jpg to ../training_val
# Copied: american_bulldog_12.jpg to ../training_val
# Copied: american_bulldog_130.jpg to ../training_val
# Copied: american_bulldog_131.jpg to ../training_val
# Copied: american_bulldog_132.jpg to ../training_val
# Copied: american_bulldog_133.jpg to ../training_val
# Copied: american_bulldog_134.jpg to ../training_val
# Copied: american_bulldog_135.jpg to ../training_val
# Copied: american_bulldog_136.jpg to ../training_val
# Copied: american_bulldog_137.jpg to ../training_val
# Copied: american_bulldog_138.jpg to ../training_val
# Copied: american_bulldog_139.jpg to ../training_val
# Copied: american_bulldog_13.jpg to ../training_val
# Copied: american_bulldog_140.jpg to ../training_val
# Copied: american_bulldog_141.jpg to ../training_val
# Copied: american_bulldog_142.jpg to ../training_val
# Copied: american_bulldog_143.jpg to ../training_val
# Copied: american_bulldog_144.jpg to ../training_val
# Copied: american_bulldog_146.jpg to ../training_val
# Copied: american_pit_bull_terrier_100.jpg to ../training_val
# Copied: american_pit_bull_terrier_101.jpg to ../training_val
# Copied: american_pit_bull_terrier_102.jpg to ../training_val
# Copied: american_pit_bull_terrier_103.jpg to ../training_val
# Copied: american_pit_bull_terrier_104.jpg to ../training_val
# Copied: american_pit_bull_terrier_105.jpg to ../training_val
# Copied: american_pit_bull_terrier_106.jpg to ../training_val
# Copied: american_pit_bull_terrier_107.jpg to ../training_val
# Copied: american_pit_bull_terrier_108.jpg to ../training_val
# Copied: american_pit_bull_terrier_109.jpg to ../training_val
# Copied: american_pit_bull_terrier_10.jpg to ../training_val
# Copied: american_pit_bull_terrier_110.jpg to ../training_val
# Copied: american_pit_bull_terrier_111.jpg to ../training_val
# Copied: american_pit_bull_terrier_112.jpg to ../training_val
# Copied: american_pit_bull_terrier_113.jpg to ../training_val
# Copied: american_pit_bull_terrier_114.jpg to ../training_val
# Copied: american_pit_bull_terrier_115.jpg to ../training_val
# Copied: american_pit_bull_terrier_116.jpg to ../training_val
# Copied: american_pit_bull_terrier_117.jpg to ../training_val
# Copied: american_pit_bull_terrier_118.jpg to ../training_val
# Copied: american_pit_bull_terrier_119.jpg to ../training_val
# Copied: american_pit_bull_terrier_11.jpg to ../training_val
# Copied: american_pit_bull_terrier_120.jpg to ../training_val
# Copied: american_pit_bull_terrier_121.jpg to ../training_val
# Copied: american_pit_bull_terrier_122.jpg to ../training_val
# Copied: american_pit_bull_terrier_123.jpg to ../training_val
# Copied: american_pit_bull_terrier_124.jpg to ../training_val
# Copied: american_pit_bull_terrier_125.jpg to ../training_val
# Copied: american_pit_bull_terrier_126.jpg to ../training_val
# Copied: american_pit_bull_terrier_127.jpg to ../training_val
# Copied: american_pit_bull_terrier_128.jpg to ../training_val
# Copied: american_pit_bull_terrier_129.jpg to ../training_val
# Copied: american_pit_bull_terrier_12.jpg to ../training_val
# Copied: american_pit_bull_terrier_130.jpg to ../training_val
# Copied: american_pit_bull_terrier_131.jpg to ../training_val
# Copied: american_pit_bull_terrier_132.jpg to ../training_val
# Copied: american_pit_bull_terrier_133.jpg to ../training_val
# Copied: american_pit_bull_terrier_134.jpg to ../training_val
# Copied: american_pit_bull_terrier_135.jpg to ../training_val
# Copied: american_pit_bull_terrier_136.jpg to ../training_val
# Copied: american_pit_bull_terrier_137.jpg to ../training_val
# Copied: american_pit_bull_terrier_138.jpg to ../training_val
# Copied: american_pit_bull_terrier_139.jpg to ../training_val
# Copied: american_pit_bull_terrier_13.jpg to ../training_val
# Copied: american_pit_bull_terrier_140.jpg to ../training_val
# Copied: american_pit_bull_terrier_141.jpg to ../training_val
# Copied: american_pit_bull_terrier_142.jpg to ../training_val
# Copied: american_pit_bull_terrier_143.jpg to ../training_val
# Copied: american_pit_bull_terrier_144.jpg to ../training_val
# Copied: american_pit_bull_terrier_145.jpg to ../training_val
# Copied: basset_hound_100.jpg to ../training_val
# Copied: basset_hound_101.jpg to ../training_val
# Copied: basset_hound_102.jpg to ../training_val
# Copied: basset_hound_103.jpg to ../training_val
# Copied: basset_hound_104.jpg to ../training_val
# Copied: basset_hound_105.jpg to ../training_val
# Copied: basset_hound_106.jpg to ../training_val
# Copied: basset_hound_107.jpg to ../training_val
# Copied: basset_hound_108.jpg to ../training_val
# Copied: basset_hound_109.jpg to ../training_val
# Copied: basset_hound_10.jpg to ../training_val
# Copied: basset_hound_110.jpg to ../training_val
# Copied: basset_hound_111.jpg to ../training_val
# Copied: basset_hound_112.jpg to ../training_val
# Copied: basset_hound_113.jpg to ../training_val
# Copied: basset_hound_114.jpg to ../training_val
# Copied: basset_hound_115.jpg to ../training_val
# Copied: basset_hound_116.jpg to ../training_val
# Copied: basset_hound_117.jpg to ../training_val
# Copied: basset_hound_118.jpg to ../training_val
# Copied: basset_hound_119.jpg to ../training_val
# Copied: basset_hound_11.jpg to ../training_val
# Copied: basset_hound_120.jpg to ../training_val
# Copied: basset_hound_121.jpg to ../training_val
# Copied: basset_hound_122.jpg to ../training_val
# Copied: basset_hound_123.jpg to ../training_val
# Copied: basset_hound_124.jpg to ../training_val
# Copied: basset_hound_125.jpg to ../training_val
# Copied: basset_hound_126.jpg to ../training_val
# Copied: basset_hound_127.jpg to ../training_val
# Copied: basset_hound_128.jpg to ../training_val
# Copied: basset_hound_129.jpg to ../training_val
# Copied: basset_hound_12.jpg to ../training_val
# Copied: basset_hound_130.jpg to ../training_val
# Copied: basset_hound_131.jpg to ../training_val
# Copied: basset_hound_132.jpg to ../training_val
# Copied: basset_hound_133.jpg to ../training_val
# Copied: basset_hound_134.jpg to ../training_val
# Copied: basset_hound_135.jpg to ../training_val
# Copied: basset_hound_136.jpg to ../training_val
# Copied: basset_hound_137.jpg to ../training_val
# Copied: basset_hound_138.jpg to ../training_val
# Copied: basset_hound_139.jpg to ../training_val
# Copied: basset_hound_13.jpg to ../training_val
# Copied: basset_hound_140.jpg to ../training_val
# Copied: basset_hound_141.jpg to ../training_val
# Copied: basset_hound_142.jpg to ../training_val
# Copied: basset_hound_143.jpg to ../training_val
# Copied: basset_hound_144.jpg to ../training_val
# Copied: basset_hound_145.jpg to ../training_val
# Copied: beagle_100.jpg to ../training_val
# Copied: beagle_101.jpg to ../training_val
# Copied: beagle_102.jpg to ../training_val
# Copied: beagle_103.jpg to ../training_val
# Copied: beagle_104.jpg to ../training_val
# Copied: beagle_105.jpg to ../training_val
# Copied: beagle_107.jpg to ../training_val
# Copied: beagle_108.jpg to ../training_val
# Copied: beagle_109.jpg to ../training_val
# Copied: beagle_10.jpg to ../training_val
# Copied: beagle_110.jpg to ../training_val
# Copied: beagle_111.jpg to ../training_val
# Copied: beagle_112.jpg to ../training_val
# Copied: beagle_113.jpg to ../training_val
# Copied: beagle_114.jpg to ../training_val
# Copied: beagle_115.jpg to ../training_val
# Copied: beagle_116.jpg to ../training_val
# Copied: beagle_117.jpg to ../training_val
# Copied: beagle_118.jpg to ../training_val
# Copied: beagle_119.jpg to ../training_val
# Copied: beagle_120.jpg to ../training_val
# Copied: beagle_121.jpg to ../training_val
# Copied: beagle_122.jpg to ../training_val
# Copied: beagle_123.jpg to ../training_val
# Copied: beagle_124.jpg to ../training_val
# Copied: beagle_125.jpg to ../training_val
# Copied: beagle_126.jpg to ../training_val
# Copied: beagle_127.jpg to ../training_val
# Copied: beagle_128.jpg to ../training_val
# Copied: beagle_129.jpg to ../training_val
# Copied: beagle_12.jpg to ../training_val
# Copied: beagle_130.jpg to ../training_val
# Copied: beagle_131.jpg to ../training_val
# Copied: beagle_133.jpg to ../training_val
# Copied: beagle_134.jpg to ../training_val
# Copied: beagle_135.jpg to ../training_val
# Copied: beagle_136.jpg to ../training_val
# Copied: beagle_137.jpg to ../training_val
# Copied: beagle_138.jpg to ../training_val
# Copied: beagle_139.jpg to ../training_val
# Copied: beagle_13.jpg to ../training_val
# Copied: beagle_140.jpg to ../training_val
# Copied: beagle_141.jpg to ../training_val
# Copied: beagle_142.jpg to ../training_val
# Copied: beagle_143.jpg to ../training_val
# Copied: beagle_144.jpg to ../training_val
# Copied: beagle_145.jpg to ../training_val
# Copied: beagle_146.jpg to ../training_val
# Copied: beagle_147.jpg to ../training_val
# Copied: beagle_148.jpg to ../training_val
# Copied: Bengal_100.jpg to ../training_val
# Copied: Bengal_101.jpg to ../training_val
# Copied: Bengal_102.jpg to ../training_val
# Copied: Bengal_103.jpg to ../training_val
# Copied: Bengal_104.jpg to ../training_val
# Copied: Bengal_105.jpg to ../training_val
# Copied: Bengal_106.jpg to ../training_val
# Copied: Bengal_107.jpg to ../training_val
# Copied: Bengal_108.jpg to ../training_val
# Copied: Bengal_109.jpg to ../training_val
# Copied: Bengal_10.jpg to ../training_val
# Copied: Bengal_110.jpg to ../training_val
# Copied: Bengal_111.jpg to ../training_val
# Copied: Bengal_112.jpg to ../training_val
# Copied: Bengal_113.jpg to ../training_val
# Copied: Bengal_114.jpg to ../training_val
# Copied: Bengal_115.jpg to ../training_val
# Copied: Bengal_116.jpg to ../training_val
# Copied: Bengal_117.jpg to ../training_val
# Copied: Bengal_118.jpg to ../training_val
# Copied: Bengal_119.jpg to ../training_val
# Copied: Bengal_11.jpg to ../training_val
# Copied: Bengal_120.jpg to ../training_val
# Copied: Bengal_121.jpg to ../training_val
# Copied: Bengal_122.jpg to ../training_val
# Copied: Bengal_123.jpg to ../training_val
# Copied: Bengal_124.jpg to ../training_val
# Copied: Bengal_125.jpg to ../training_val
# Copied: Bengal_126.jpg to ../training_val
# Copied: Bengal_127.jpg to ../training_val
# Copied: Bengal_128.jpg to ../training_val
# Copied: Bengal_129.jpg to ../training_val
# Copied: Bengal_12.jpg to ../training_val
# Copied: Bengal_130.jpg to ../training_val
# Copied: Bengal_131.jpg to ../training_val
# Copied: Bengal_132.jpg to ../training_val
# Copied: Bengal_133.jpg to ../training_val
# Copied: Bengal_134.jpg to ../training_val
# Copied: Bengal_135.jpg to ../training_val
# Copied: Bengal_136.jpg to ../training_val
# Copied: Bengal_137.jpg to ../training_val
# Copied: Bengal_138.jpg to ../training_val
# Copied: Bengal_139.jpg to ../training_val
# Copied: Bengal_13.jpg to ../training_val
# Copied: Bengal_140.jpg to ../training_val
# Copied: Bengal_141.jpg to ../training_val
# Copied: Bengal_142.jpg to ../training_val
# Copied: Bengal_143.jpg to ../training_val
# Copied: Bengal_144.jpg to ../training_val
# Copied: Bengal_145.jpg to ../training_val
# Copied: Birman_100.jpg to ../training_val
# Copied: Birman_101.jpg to ../training_val
# Copied: Birman_102.jpg to ../training_val
# Copied: Birman_103.jpg to ../training_val
# Copied: Birman_104.jpg to ../training_val
# Copied: Birman_105.jpg to ../training_val
# Copied: Birman_106.jpg to ../training_val
# Copied: Birman_107.jpg to ../training_val
# Copied: Birman_108.jpg to ../training_val
# Copied: Birman_109.jpg to ../training_val
# Copied: Birman_10.jpg to ../training_val
# Copied: Birman_110.jpg to ../training_val
# Copied: Birman_111.jpg to ../training_val
# Copied: Birman_112.jpg to ../training_val
# Copied: Birman_113.jpg to ../training_val
# Copied: Birman_114.jpg to ../training_val
# Copied: Birman_115.jpg to ../training_val
# Copied: Birman_116.jpg to ../training_val
# Copied: Birman_117.jpg to ../training_val
# Copied: Birman_118.jpg to ../training_val
# Copied: Birman_119.jpg to ../training_val
# Copied: Birman_11.jpg to ../training_val
# Copied: Birman_120.jpg to ../training_val
# Copied: Birman_121.jpg to ../training_val
# Copied: Birman_122.jpg to ../training_val
# Copied: Birman_123.jpg to ../training_val
# Copied: Birman_124.jpg to ../training_val
# Copied: Birman_125.jpg to ../training_val
# Copied: Birman_126.jpg to ../training_val
# Copied: Birman_127.jpg to ../training_val
# Copied: Birman_128.jpg to ../training_val
# Copied: Birman_129.jpg to ../training_val
# Copied: Birman_12.jpg to ../training_val
# Copied: Birman_130.jpg to ../training_val
# Copied: Birman_131.jpg to ../training_val
# Copied: Birman_132.jpg to ../training_val
# Copied: Birman_133.jpg to ../training_val
# Copied: Birman_134.jpg to ../training_val
# Copied: Birman_135.jpg to ../training_val
# Copied: Birman_136.jpg to ../training_val
# Copied: Birman_137.jpg to ../training_val
# Copied: Birman_138.jpg to ../training_val
# Copied: Birman_139.jpg to ../training_val
# Copied: Birman_13.jpg to ../training_val
# Copied: Birman_140.jpg to ../training_val
# Copied: Birman_141.jpg to ../training_val
# Copied: Birman_142.jpg to ../training_val
# Copied: Birman_143.jpg to ../training_val
# Copied: Birman_144.jpg to ../training_val
# Copied: Birman_145.jpg to ../training_val
# Copied: Bombay_100.jpg to ../training_val
# Copied: Bombay_101.jpg to ../training_val
# Copied: Bombay_102.jpg to ../training_val
# Copied: Bombay_103.jpg to ../training_val
# Copied: Bombay_104.jpg to ../training_val
# Copied: Bombay_105.jpg to ../training_val
# Copied: Bombay_106.jpg to ../training_val
# Copied: Bombay_107.jpg to ../training_val
# Copied: Bombay_108.jpg to ../training_val
# Copied: Bombay_109.jpg to ../training_val
# Copied: Bombay_10.jpg to ../training_val
# Copied: Bombay_110.jpg to ../training_val
# Copied: Bombay_111.jpg to ../training_val
# Copied: Bombay_112.jpg to ../training_val
# Copied: Bombay_113.jpg to ../training_val
# Copied: Bombay_114.jpg to ../training_val
# Copied: Bombay_115.jpg to ../training_val
# Copied: Bombay_116.jpg to ../training_val
# Copied: Bombay_117.jpg to ../training_val
# Copied: Bombay_118.jpg to ../training_val
# Copied: Bombay_119.jpg to ../training_val
# Copied: Bombay_120.jpg to ../training_val
# Copied: Bombay_121.jpg to ../training_val
# Copied: Bombay_122.jpg to ../training_val
# Copied: Bombay_123.jpg to ../training_val
# Copied: Bombay_125.jpg to ../training_val
# Copied: Bombay_126.jpg to ../training_val
# Copied: Bombay_127.jpg to ../training_val
# Copied: Bombay_128.jpg to ../training_val
# Copied: Bombay_129.jpg to ../training_val
# Copied: Bombay_12.jpg to ../training_val
# Copied: Bombay_130.jpg to ../training_val
# Copied: Bombay_131.jpg to ../training_val
# Copied: Bombay_132.jpg to ../training_val
# Copied: Bombay_133.jpg to ../training_val
# Copied: Bombay_134.jpg to ../training_val
# Copied: Bombay_135.jpg to ../training_val
# Copied: Bombay_136.jpg to ../training_val
# Copied: Bombay_137.jpg to ../training_val
# Copied: Bombay_138.jpg to ../training_val
# Copied: Bombay_139.jpg to ../training_val
# Copied: Bombay_13.jpg to ../training_val
# Copied: Bombay_140.jpg to ../training_val
# Copied: Bombay_141.jpg to ../training_val
# Copied: Bombay_143.jpg to ../training_val
# Copied: Bombay_144.jpg to ../training_val
# Copied: Bombay_145.jpg to ../training_val
# Copied: Bombay_146.jpg to ../training_val
# Copied: Bombay_148.jpg to ../training_val
# Copied: boxer_100.jpg to ../training_val
# Copied: boxer_101.jpg to ../training_val
# Copied: boxer_102.jpg to ../training_val
# Copied: boxer_103.jpg to ../training_val
# Copied: boxer_104.jpg to ../training_val
# Copied: boxer_105.jpg to ../training_val
# Copied: boxer_106.jpg to ../training_val
# Copied: boxer_107.jpg to ../training_val
# Copied: boxer_108.jpg to ../training_val
# Copied: boxer_109.jpg to ../training_val
# Copied: boxer_10.jpg to ../training_val
# Copied: boxer_110.jpg to ../training_val
# Copied: boxer_111.jpg to ../training_val
# Copied: boxer_112.jpg to ../training_val
# Copied: boxer_113.jpg to ../training_val
# Copied: boxer_114.jpg to ../training_val
# Copied: boxer_115.jpg to ../training_val
# Copied: boxer_116.jpg to ../training_val
# Copied: boxer_117.jpg to ../training_val
# Copied: boxer_118.jpg to ../training_val
# Copied: boxer_119.jpg to ../training_val
# Copied: boxer_11.jpg to ../training_val
# Copied: boxer_120.jpg to ../training_val
# Copied: boxer_121.jpg to ../training_val
# Copied: boxer_122.jpg to ../training_val
# Copied: boxer_123.jpg to ../training_val
# Copied: boxer_124.jpg to ../training_val
# Copied: boxer_125.jpg to ../training_val
# Copied: boxer_126.jpg to ../training_val
# Copied: boxer_127.jpg to ../training_val
# Copied: boxer_128.jpg to ../training_val
# Copied: boxer_129.jpg to ../training_val
# Copied: boxer_12.jpg to ../training_val
# Copied: boxer_130.jpg to ../training_val
# Copied: boxer_131.jpg to ../training_val
# Copied: boxer_132.jpg to ../training_val
# Copied: boxer_133.jpg to ../training_val
# Copied: boxer_134.jpg to ../training_val
# Copied: boxer_135.jpg to ../training_val
# Copied: boxer_136.jpg to ../training_val
# Copied: boxer_137.jpg to ../training_val
# Copied: boxer_138.jpg to ../training_val
# Copied: boxer_139.jpg to ../training_val
# Copied: boxer_13.jpg to ../training_val
# Copied: boxer_140.jpg to ../training_val
# Copied: boxer_141.jpg to ../training_val
# Copied: boxer_142.jpg to ../training_val
# Copied: boxer_143.jpg to ../training_val
# Copied: boxer_144.jpg to ../training_val
# Copied: boxer_145.jpg to ../training_val
# Copied: British_Shorthair_100.jpg to ../training_val
# Copied: British_Shorthair_101.jpg to ../training_val
# Copied: British_Shorthair_102.jpg to ../training_val
# Copied: British_Shorthair_103.jpg to ../training_val
# Copied: British_Shorthair_104.jpg to ../training_val
# Copied: British_Shorthair_105.jpg to ../training_val
# Copied: British_Shorthair_106.jpg to ../training_val
# Copied: British_Shorthair_107.jpg to ../training_val
# Copied: British_Shorthair_108.jpg to ../training_val
# Copied: British_Shorthair_109.jpg to ../training_val
# Copied: British_Shorthair_10.jpg to ../training_val
# Copied: British_Shorthair_110.jpg to ../training_val
# Copied: British_Shorthair_111.jpg to ../training_val
# Copied: British_Shorthair_112.jpg to ../training_val
# Copied: British_Shorthair_113.jpg to ../training_val
# Copied: British_Shorthair_114.jpg to ../training_val
# Copied: British_Shorthair_115.jpg to ../training_val
# Copied: British_Shorthair_116.jpg to ../training_val
# Copied: British_Shorthair_117.jpg to ../training_val
# Copied: British_Shorthair_118.jpg to ../training_val
# Copied: British_Shorthair_119.jpg to ../training_val
# Copied: British_Shorthair_120.jpg to ../training_val
# Copied: British_Shorthair_121.jpg to ../training_val
# Copied: British_Shorthair_122.jpg to ../training_val
# Copied: British_Shorthair_123.jpg to ../training_val
# Copied: British_Shorthair_124.jpg to ../training_val
# Copied: British_Shorthair_125.jpg to ../training_val
# Copied: British_Shorthair_126.jpg to ../training_val
# Copied: British_Shorthair_127.jpg to ../training_val
# Copied: British_Shorthair_128.jpg to ../training_val
# Copied: British_Shorthair_129.jpg to ../training_val
# Copied: British_Shorthair_130.jpg to ../training_val
# Copied: British_Shorthair_133.jpg to ../training_val
# Copied: British_Shorthair_134.jpg to ../training_val
# Copied: British_Shorthair_135.jpg to ../training_val
# Copied: British_Shorthair_136.jpg to ../training_val
# Copied: British_Shorthair_137.jpg to ../training_val
# Copied: British_Shorthair_139.jpg to ../training_val
# Copied: British_Shorthair_140.jpg to ../training_val
# Copied: British_Shorthair_141.jpg to ../training_val
# Copied: British_Shorthair_144.jpg to ../training_val
# Copied: British_Shorthair_145.jpg to ../training_val
# Copied: British_Shorthair_148.jpg to ../training_val
# Copied: British_Shorthair_149.jpg to ../training_val
# Copied: British_Shorthair_151.jpg to ../training_val
# Copied: British_Shorthair_153.jpg to ../training_val
# Copied: British_Shorthair_154.jpg to ../training_val
# Copied: British_Shorthair_155.jpg to ../training_val
# Copied: British_Shorthair_156.jpg to ../training_val
# Copied: British_Shorthair_157.jpg to ../training_val
# Copied: chihuahua_100.jpg to ../training_val
# Copied: chihuahua_101.jpg to ../training_val
# Copied: chihuahua_102.jpg to ../training_val
# Copied: chihuahua_103.jpg to ../training_val
# Copied: chihuahua_104.jpg to ../training_val
# Copied: chihuahua_105.jpg to ../training_val
# Copied: chihuahua_106.jpg to ../training_val
# Copied: chihuahua_107.jpg to ../training_val
# Copied: chihuahua_108.jpg to ../training_val
# Copied: chihuahua_109.jpg to ../training_val
# Copied: chihuahua_10.jpg to ../training_val
# Copied: chihuahua_110.jpg to ../training_val
# Copied: chihuahua_111.jpg to ../training_val
# Copied: chihuahua_112.jpg to ../training_val
# Copied: chihuahua_113.jpg to ../training_val
# Copied: chihuahua_114.jpg to ../training_val
# Copied: chihuahua_115.jpg to ../training_val
# Copied: chihuahua_116.jpg to ../training_val
# Copied: chihuahua_117.jpg to ../training_val
# Copied: chihuahua_118.jpg to ../training_val
# Copied: chihuahua_119.jpg to ../training_val
# Copied: chihuahua_11.jpg to ../training_val
# Copied: chihuahua_120.jpg to ../training_val
# Copied: chihuahua_121.jpg to ../training_val
# Copied: chihuahua_122.jpg to ../training_val
# Copied: chihuahua_123.jpg to ../training_val
# Copied: chihuahua_124.jpg to ../training_val
# Copied: chihuahua_125.jpg to ../training_val
# Copied: chihuahua_126.jpg to ../training_val
# Copied: chihuahua_127.jpg to ../training_val
# Copied: chihuahua_128.jpg to ../training_val
# Copied: chihuahua_129.jpg to ../training_val
# Copied: chihuahua_12.jpg to ../training_val
# Copied: chihuahua_130.jpg to ../training_val
# Copied: chihuahua_131.jpg to ../training_val
# Copied: chihuahua_132.jpg to ../training_val
# Copied: chihuahua_133.jpg to ../training_val
# Copied: chihuahua_134.jpg to ../training_val
# Copied: chihuahua_135.jpg to ../training_val
# Copied: chihuahua_136.jpg to ../training_val
# Copied: chihuahua_137.jpg to ../training_val
# Copied: chihuahua_138.jpg to ../training_val
# Copied: chihuahua_139.jpg to ../training_val
# Copied: chihuahua_13.jpg to ../training_val
# Copied: chihuahua_140.jpg to ../training_val
# Copied: chihuahua_141.jpg to ../training_val
# Copied: chihuahua_142.jpg to ../training_val
# Copied: chihuahua_143.jpg to ../training_val
# Copied: chihuahua_144.jpg to ../training_val
# Copied: chihuahua_145.jpg to ../training_val
# Copied: Egyptian_Mau_100.jpg to ../training_val
# Copied: Egyptian_Mau_101.jpg to ../training_val
# Copied: Egyptian_Mau_102.jpg to ../training_val
# Copied: Egyptian_Mau_103.jpg to ../training_val
# Copied: Egyptian_Mau_104.jpg to ../training_val
# Copied: Egyptian_Mau_105.jpg to ../training_val
# Copied: Egyptian_Mau_106.jpg to ../training_val
# Copied: Egyptian_Mau_107.jpg to ../training_val
# Copied: Egyptian_Mau_108.jpg to ../training_val
# Copied: Egyptian_Mau_109.jpg to ../training_val
# Copied: Egyptian_Mau_10.jpg to ../training_val
# Copied: Egyptian_Mau_110.jpg to ../training_val
# Copied: Egyptian_Mau_111.jpg to ../training_val
# Copied: Egyptian_Mau_112.jpg to ../training_val
# Copied: Egyptian_Mau_113.jpg to ../training_val
# Copied: Egyptian_Mau_114.jpg to ../training_val
# Copied: Egyptian_Mau_115.jpg to ../training_val
# Copied: Egyptian_Mau_116.jpg to ../training_val
# Copied: Egyptian_Mau_117.jpg to ../training_val
# Copied: Egyptian_Mau_118.jpg to ../training_val
# Copied: Egyptian_Mau_119.jpg to ../training_val
# Copied: Egyptian_Mau_11.jpg to ../training_val
# Copied: Egyptian_Mau_120.jpg to ../training_val
# Copied: Egyptian_Mau_121.jpg to ../training_val
# Copied: Egyptian_Mau_122.jpg to ../training_val
# Copied: Egyptian_Mau_123.jpg to ../training_val
# Copied: Egyptian_Mau_124.jpg to ../training_val
# Copied: Egyptian_Mau_125.jpg to ../training_val
# Copied: Egyptian_Mau_126.jpg to ../training_val
# Copied: Egyptian_Mau_127.jpg to ../training_val
# Copied: Egyptian_Mau_128.jpg to ../training_val
# Copied: Egyptian_Mau_12.jpg to ../training_val
# Copied: Egyptian_Mau_130.jpg to ../training_val
# Copied: Egyptian_Mau_131.jpg to ../training_val
# Copied: Egyptian_Mau_132.jpg to ../training_val
# Copied: Egyptian_Mau_133.jpg to ../training_val
# Copied: Egyptian_Mau_134.jpg to ../training_val
# Copied: Egyptian_Mau_136.jpg to ../training_val
# Copied: Egyptian_Mau_138.jpg to ../training_val
# Copied: Egyptian_Mau_13.jpg to ../training_val
# Copied: Egyptian_Mau_140.jpg to ../training_val
# Copied: Egyptian_Mau_141.jpg to ../training_val
# Copied: Egyptian_Mau_142.jpg to ../training_val
# Copied: Egyptian_Mau_143.jpg to ../training_val
# Copied: Egyptian_Mau_144.jpg to ../training_val
# Copied: Egyptian_Mau_146.jpg to ../training_val
# Copied: Egyptian_Mau_147.jpg to ../training_val
# Copied: english_cocker_spaniel_100.jpg to ../training_val
# Copied: english_cocker_spaniel_101.jpg to ../training_val
# Copied: english_cocker_spaniel_102.jpg to ../training_val
# Copied: english_cocker_spaniel_103.jpg to ../training_val
# Copied: english_cocker_spaniel_104.jpg to ../training_val
# Copied: english_cocker_spaniel_105.jpg to ../training_val
# Copied: english_cocker_spaniel_106.jpg to ../training_val
# Copied: english_cocker_spaniel_107.jpg to ../training_val
# Copied: english_cocker_spaniel_108.jpg to ../training_val
# Copied: english_cocker_spaniel_109.jpg to ../training_val
# Copied: english_cocker_spaniel_10.jpg to ../training_val
# Copied: english_cocker_spaniel_110.jpg to ../training_val
# Copied: english_cocker_spaniel_111.jpg to ../training_val
# Copied: english_cocker_spaniel_112.jpg to ../training_val
# Copied: english_cocker_spaniel_113.jpg to ../training_val
# Copied: english_cocker_spaniel_114.jpg to ../training_val
# Copied: english_cocker_spaniel_115.jpg to ../training_val
# Copied: english_cocker_spaniel_116.jpg to ../training_val
# Copied: english_cocker_spaniel_117.jpg to ../training_val
# Copied: english_cocker_spaniel_118.jpg to ../training_val
# Copied: english_cocker_spaniel_119.jpg to ../training_val
# Copied: english_cocker_spaniel_11.jpg to ../training_val
# Copied: english_cocker_spaniel_120.jpg to ../training_val
# Copied: english_cocker_spaniel_121.jpg to ../training_val
# Copied: english_cocker_spaniel_122.jpg to ../training_val
# Copied: english_cocker_spaniel_123.jpg to ../training_val
# Copied: english_cocker_spaniel_124.jpg to ../training_val
# Copied: english_cocker_spaniel_125.jpg to ../training_val
# Copied: english_cocker_spaniel_126.jpg to ../training_val
# Copied: english_cocker_spaniel_127.jpg to ../training_val
# Copied: english_cocker_spaniel_128.jpg to ../training_val
# Copied: english_cocker_spaniel_129.jpg to ../training_val
# Copied: english_cocker_spaniel_12.jpg to ../training_val
# Copied: english_cocker_spaniel_130.jpg to ../training_val
# Copied: english_cocker_spaniel_131.jpg to ../training_val
# Copied: english_cocker_spaniel_132.jpg to ../training_val
# Copied: english_cocker_spaniel_133.jpg to ../training_val
# Copied: english_cocker_spaniel_134.jpg to ../training_val
# Copied: english_cocker_spaniel_135.jpg to ../training_val
# Copied: english_cocker_spaniel_136.jpg to ../training_val
# Copied: english_cocker_spaniel_137.jpg to ../training_val
# Copied: english_cocker_spaniel_138.jpg to ../training_val
# Copied: english_cocker_spaniel_139.jpg to ../training_val
# Copied: english_cocker_spaniel_13.jpg to ../training_val
# Copied: english_cocker_spaniel_140.jpg to ../training_val
# Copied: english_cocker_spaniel_141.jpg to ../training_val
# Copied: english_cocker_spaniel_142.jpg to ../training_val
# Copied: english_cocker_spaniel_143.jpg to ../training_val
# Copied: english_cocker_spaniel_144.jpg to ../training_val
# Copied: english_cocker_spaniel_145.jpg to ../training_val
# Copied: english_setter_100.jpg to ../training_val
# Copied: english_setter_101.jpg to ../training_val
# Copied: english_setter_102.jpg to ../training_val
# Copied: english_setter_103.jpg to ../training_val
# Copied: english_setter_104.jpg to ../training_val
# Copied: english_setter_105.jpg to ../training_val
# Copied: english_setter_106.jpg to ../training_val
# Copied: english_setter_107.jpg to ../training_val
# Copied: english_setter_108.jpg to ../training_val
# Copied: english_setter_109.jpg to ../training_val
# Copied: english_setter_10.jpg to ../training_val
# Copied: english_setter_110.jpg to ../training_val
# Copied: english_setter_111.jpg to ../training_val
# Copied: english_setter_112.jpg to ../training_val
# Copied: english_setter_113.jpg to ../training_val
# Copied: english_setter_114.jpg to ../training_val
# Copied: english_setter_115.jpg to ../training_val
# Copied: english_setter_116.jpg to ../training_val
# Copied: english_setter_117.jpg to ../training_val
# Copied: english_setter_118.jpg to ../training_val
# Copied: english_setter_119.jpg to ../training_val
# Copied: english_setter_11.jpg to ../training_val
# Copied: english_setter_120.jpg to ../training_val
# Copied: english_setter_121.jpg to ../training_val
# Copied: english_setter_122.jpg to ../training_val
# Copied: english_setter_123.jpg to ../training_val
# Copied: english_setter_124.jpg to ../training_val
# Copied: english_setter_125.jpg to ../training_val
# Copied: english_setter_126.jpg to ../training_val
# Copied: english_setter_127.jpg to ../training_val
# Copied: english_setter_128.jpg to ../training_val
# Copied: english_setter_129.jpg to ../training_val
# Copied: english_setter_12.jpg to ../training_val
# Copied: english_setter_130.jpg to ../training_val
# Copied: english_setter_131.jpg to ../training_val
# Copied: english_setter_132.jpg to ../training_val
# Copied: english_setter_133.jpg to ../training_val
# Copied: english_setter_134.jpg to ../training_val
# Copied: english_setter_135.jpg to ../training_val
# Copied: english_setter_136.jpg to ../training_val
# Copied: english_setter_137.jpg to ../training_val
# Copied: english_setter_138.jpg to ../training_val
# Copied: english_setter_139.jpg to ../training_val
# Copied: english_setter_13.jpg to ../training_val
# Copied: english_setter_140.jpg to ../training_val
# Copied: english_setter_141.jpg to ../training_val
# Copied: english_setter_142.jpg to ../training_val
# Copied: english_setter_143.jpg to ../training_val
# Copied: english_setter_144.jpg to ../training_val
# Copied: english_setter_145.jpg to ../training_val
# Copied: german_shorthaired_100.jpg to ../training_val
# Copied: german_shorthaired_101.jpg to ../training_val
# Copied: german_shorthaired_102.jpg to ../training_val
# Copied: german_shorthaired_103.jpg to ../training_val
# Copied: german_shorthaired_104.jpg to ../training_val
# Copied: german_shorthaired_105.jpg to ../training_val
# Copied: german_shorthaired_106.jpg to ../training_val
# Copied: german_shorthaired_107.jpg to ../training_val
# Copied: german_shorthaired_108.jpg to ../training_val
# Copied: german_shorthaired_109.jpg to ../training_val
# Copied: german_shorthaired_10.jpg to ../training_val
# Copied: german_shorthaired_110.jpg to ../training_val
# Copied: german_shorthaired_111.jpg to ../training_val
# Copied: german_shorthaired_112.jpg to ../training_val
# Copied: german_shorthaired_113.jpg to ../training_val
# Copied: german_shorthaired_114.jpg to ../training_val
# Copied: german_shorthaired_115.jpg to ../training_val
# Copied: german_shorthaired_116.jpg to ../training_val
# Copied: german_shorthaired_117.jpg to ../training_val
# Copied: german_shorthaired_118.jpg to ../training_val
# Copied: german_shorthaired_119.jpg to ../training_val
# Copied: german_shorthaired_11.jpg to ../training_val
# Copied: german_shorthaired_120.jpg to ../training_val
# Copied: german_shorthaired_121.jpg to ../training_val
# Copied: german_shorthaired_122.jpg to ../training_val
# Copied: german_shorthaired_123.jpg to ../training_val
# Copied: german_shorthaired_124.jpg to ../training_val
# Copied: german_shorthaired_125.jpg to ../training_val
# Copied: german_shorthaired_126.jpg to ../training_val
# Copied: german_shorthaired_127.jpg to ../training_val
# Copied: german_shorthaired_128.jpg to ../training_val
# Copied: german_shorthaired_129.jpg to ../training_val
# Copied: german_shorthaired_12.jpg to ../training_val
# Copied: german_shorthaired_130.jpg to ../training_val
# Copied: german_shorthaired_131.jpg to ../training_val
# Copied: german_shorthaired_132.jpg to ../training_val
# Copied: german_shorthaired_133.jpg to ../training_val
# Copied: german_shorthaired_134.jpg to ../training_val
# Copied: german_shorthaired_135.jpg to ../training_val
# Copied: german_shorthaired_136.jpg to ../training_val
# Copied: german_shorthaired_137.jpg to ../training_val
# Copied: german_shorthaired_138.jpg to ../training_val
# Copied: german_shorthaired_139.jpg to ../training_val
# Copied: german_shorthaired_13.jpg to ../training_val
# Copied: german_shorthaired_140.jpg to ../training_val
# Copied: german_shorthaired_141.jpg to ../training_val
# Copied: german_shorthaired_142.jpg to ../training_val
# Copied: german_shorthaired_143.jpg to ../training_val
# Copied: german_shorthaired_144.jpg to ../training_val
# Copied: german_shorthaired_145.jpg to ../training_val
# Copied: great_pyrenees_100.jpg to ../training_val
# Copied: great_pyrenees_101.jpg to ../training_val
# Copied: great_pyrenees_102.jpg to ../training_val
# Copied: great_pyrenees_103.jpg to ../training_val
# Copied: great_pyrenees_104.jpg to ../training_val
# Copied: great_pyrenees_105.jpg to ../training_val
# Copied: great_pyrenees_106.jpg to ../training_val
# Copied: great_pyrenees_107.jpg to ../training_val
# Copied: great_pyrenees_108.jpg to ../training_val
# Copied: great_pyrenees_109.jpg to ../training_val
# Copied: great_pyrenees_10.jpg to ../training_val
# Copied: great_pyrenees_110.jpg to ../training_val
# Copied: great_pyrenees_111.jpg to ../training_val
# Copied: great_pyrenees_112.jpg to ../training_val
# Copied: great_pyrenees_113.jpg to ../training_val
# Copied: great_pyrenees_114.jpg to ../training_val
# Copied: great_pyrenees_115.jpg to ../training_val
# Copied: great_pyrenees_116.jpg to ../training_val
# Copied: great_pyrenees_117.jpg to ../training_val
# Copied: great_pyrenees_118.jpg to ../training_val
# Copied: great_pyrenees_119.jpg to ../training_val
# Copied: great_pyrenees_11.jpg to ../training_val
# Copied: great_pyrenees_120.jpg to ../training_val
# Copied: great_pyrenees_121.jpg to ../training_val
# Copied: great_pyrenees_122.jpg to ../training_val
# Copied: great_pyrenees_123.jpg to ../training_val
# Copied: great_pyrenees_124.jpg to ../training_val
# Copied: great_pyrenees_125.jpg to ../training_val
# Copied: great_pyrenees_126.jpg to ../training_val
# Copied: great_pyrenees_127.jpg to ../training_val
# Copied: great_pyrenees_128.jpg to ../training_val
# Copied: great_pyrenees_129.jpg to ../training_val
# Copied: great_pyrenees_12.jpg to ../training_val
# Copied: great_pyrenees_130.jpg to ../training_val
# Copied: great_pyrenees_131.jpg to ../training_val
# Copied: great_pyrenees_132.jpg to ../training_val
# Copied: great_pyrenees_133.jpg to ../training_val
# Copied: great_pyrenees_134.jpg to ../training_val
# Copied: great_pyrenees_135.jpg to ../training_val
# Copied: great_pyrenees_136.jpg to ../training_val
# Copied: great_pyrenees_137.jpg to ../training_val
# Copied: great_pyrenees_138.jpg to ../training_val
# Copied: great_pyrenees_139.jpg to ../training_val
# Copied: great_pyrenees_13.jpg to ../training_val
# Copied: great_pyrenees_140.jpg to ../training_val
# Copied: great_pyrenees_141.jpg to ../training_val
# Copied: great_pyrenees_142.jpg to ../training_val
# Copied: great_pyrenees_143.jpg to ../training_val
# Copied: great_pyrenees_144.jpg to ../training_val
# Copied: great_pyrenees_145.jpg to ../training_val
# Copied: havanese_100.jpg to ../training_val
# Copied: havanese_101.jpg to ../training_val
# Copied: havanese_102.jpg to ../training_val
# Copied: havanese_103.jpg to ../training_val
# Copied: havanese_104.jpg to ../training_val
# Copied: havanese_105.jpg to ../training_val
# Copied: havanese_106.jpg to ../training_val
# Copied: havanese_107.jpg to ../training_val
# Copied: havanese_108.jpg to ../training_val
# Copied: havanese_109.jpg to ../training_val
# Copied: havanese_10.jpg to ../training_val
# Copied: havanese_110.jpg to ../training_val
# Copied: havanese_111.jpg to ../training_val
# Copied: havanese_112.jpg to ../training_val
# Copied: havanese_113.jpg to ../training_val
# Copied: havanese_114.jpg to ../training_val
# Copied: havanese_115.jpg to ../training_val
# Copied: havanese_116.jpg to ../training_val
# Copied: havanese_117.jpg to ../training_val
# Copied: havanese_118.jpg to ../training_val
# Copied: havanese_119.jpg to ../training_val
# Copied: havanese_11.jpg to ../training_val
# Copied: havanese_120.jpg to ../training_val
# Copied: havanese_121.jpg to ../training_val
# Copied: havanese_122.jpg to ../training_val
# Copied: havanese_123.jpg to ../training_val
# Copied: havanese_124.jpg to ../training_val
# Copied: havanese_125.jpg to ../training_val
# Copied: havanese_126.jpg to ../training_val
# Copied: havanese_127.jpg to ../training_val
# Copied: havanese_128.jpg to ../training_val
# Copied: havanese_129.jpg to ../training_val
# Copied: havanese_12.jpg to ../training_val
# Copied: havanese_130.jpg to ../training_val
# Copied: havanese_131.jpg to ../training_val
# Copied: havanese_132.jpg to ../training_val
# Copied: havanese_133.jpg to ../training_val
# Copied: havanese_134.jpg to ../training_val
# Copied: havanese_135.jpg to ../training_val
# Copied: havanese_136.jpg to ../training_val
# Copied: havanese_137.jpg to ../training_val
# Copied: havanese_138.jpg to ../training_val
# Copied: havanese_139.jpg to ../training_val
# Copied: havanese_13.jpg to ../training_val
# Copied: havanese_140.jpg to ../training_val
# Copied: havanese_141.jpg to ../training_val
# Copied: havanese_142.jpg to ../training_val
# Copied: havanese_143.jpg to ../training_val
# Copied: havanese_144.jpg to ../training_val
# Copied: havanese_145.jpg to ../training_val
# Copied: japanese_chin_100.jpg to ../training_val
# Copied: japanese_chin_101.jpg to ../training_val
# Copied: japanese_chin_102.jpg to ../training_val
# Copied: japanese_chin_103.jpg to ../training_val
# Copied: japanese_chin_104.jpg to ../training_val
# Copied: japanese_chin_105.jpg to ../training_val
# Copied: japanese_chin_106.jpg to ../training_val
# Copied: japanese_chin_107.jpg to ../training_val
# Copied: japanese_chin_108.jpg to ../training_val
# Copied: japanese_chin_109.jpg to ../training_val
# Copied: japanese_chin_10.jpg to ../training_val
# Copied: japanese_chin_110.jpg to ../training_val
# Copied: japanese_chin_111.jpg to ../training_val
# Copied: japanese_chin_112.jpg to ../training_val
# Copied: japanese_chin_113.jpg to ../training_val
# Copied: japanese_chin_114.jpg to ../training_val
# Copied: japanese_chin_115.jpg to ../training_val
# Copied: japanese_chin_116.jpg to ../training_val
# Copied: japanese_chin_117.jpg to ../training_val
# Copied: japanese_chin_118.jpg to ../training_val
# Copied: japanese_chin_119.jpg to ../training_val
# Copied: japanese_chin_11.jpg to ../training_val
# Copied: japanese_chin_120.jpg to ../training_val
# Copied: japanese_chin_121.jpg to ../training_val
# Copied: japanese_chin_122.jpg to ../training_val
# Copied: japanese_chin_123.jpg to ../training_val
# Copied: japanese_chin_124.jpg to ../training_val
# Copied: japanese_chin_125.jpg to ../training_val
# Copied: japanese_chin_126.jpg to ../training_val
# Copied: japanese_chin_127.jpg to ../training_val
# Copied: japanese_chin_128.jpg to ../training_val
# Copied: japanese_chin_129.jpg to ../training_val
# Copied: japanese_chin_12.jpg to ../training_val
# Copied: japanese_chin_130.jpg to ../training_val
# Copied: japanese_chin_131.jpg to ../training_val
# Copied: japanese_chin_132.jpg to ../training_val
# Copied: japanese_chin_133.jpg to ../training_val
# Copied: japanese_chin_134.jpg to ../training_val
# Copied: japanese_chin_135.jpg to ../training_val
# Copied: japanese_chin_136.jpg to ../training_val
# Copied: japanese_chin_137.jpg to ../training_val
# Copied: japanese_chin_138.jpg to ../training_val
# Copied: japanese_chin_139.jpg to ../training_val
# Copied: japanese_chin_13.jpg to ../training_val
# Copied: japanese_chin_140.jpg to ../training_val
# Copied: japanese_chin_141.jpg to ../training_val
# Copied: japanese_chin_142.jpg to ../training_val
# Copied: japanese_chin_143.jpg to ../training_val
# Copied: japanese_chin_144.jpg to ../training_val
# Copied: japanese_chin_145.jpg to ../training_val
# Copied: keeshond_100.jpg to ../training_val
# Copied: keeshond_101.jpg to ../training_val
# Copied: keeshond_102.jpg to ../training_val
# Copied: keeshond_103.jpg to ../training_val
# Copied: keeshond_104.jpg to ../training_val
# Copied: keeshond_105.jpg to ../training_val
# Copied: keeshond_106.jpg to ../training_val
# Copied: keeshond_107.jpg to ../training_val
# Copied: keeshond_108.jpg to ../training_val
# Copied: keeshond_109.jpg to ../training_val
# Copied: keeshond_10.jpg to ../training_val
# Copied: keeshond_110.jpg to ../training_val
# Copied: keeshond_111.jpg to ../training_val
# Copied: keeshond_112.jpg to ../training_val
# Copied: keeshond_113.jpg to ../training_val
# Copied: keeshond_114.jpg to ../training_val
# Copied: keeshond_115.jpg to ../training_val
# Copied: keeshond_116.jpg to ../training_val
# Copied: keeshond_117.jpg to ../training_val
# Copied: keeshond_118.jpg to ../training_val
# Copied: keeshond_119.jpg to ../training_val
# Copied: keeshond_11.jpg to ../training_val
# Copied: keeshond_120.jpg to ../training_val
# Copied: keeshond_121.jpg to ../training_val
# Copied: keeshond_122.jpg to ../training_val
# Copied: keeshond_123.jpg to ../training_val
# Copied: keeshond_124.jpg to ../training_val
# Copied: keeshond_125.jpg to ../training_val
# Copied: keeshond_126.jpg to ../training_val
# Copied: keeshond_127.jpg to ../training_val
# Copied: keeshond_128.jpg to ../training_val
# Copied: keeshond_129.jpg to ../training_val
# Copied: keeshond_12.jpg to ../training_val
# Copied: keeshond_130.jpg to ../training_val
# Copied: keeshond_131.jpg to ../training_val
# Copied: keeshond_132.jpg to ../training_val
# Copied: keeshond_133.jpg to ../training_val
# Copied: keeshond_134.jpg to ../training_val
# Copied: keeshond_135.jpg to ../training_val
# Copied: keeshond_136.jpg to ../training_val
# Copied: keeshond_137.jpg to ../training_val
# Copied: keeshond_138.jpg to ../training_val
# Copied: keeshond_139.jpg to ../training_val
# Copied: keeshond_13.jpg to ../training_val
# Copied: keeshond_140.jpg to ../training_val
# Copied: keeshond_141.jpg to ../training_val
# Copied: keeshond_142.jpg to ../training_val
# Copied: keeshond_143.jpg to ../training_val
# Copied: keeshond_144.jpg to ../training_val
# Copied: keeshond_145.jpg to ../training_val
# Copied: leonberger_100.jpg to ../training_val
# Copied: leonberger_101.jpg to ../training_val
# Copied: leonberger_102.jpg to ../training_val
# Copied: leonberger_103.jpg to ../training_val
# Copied: leonberger_104.jpg to ../training_val
# Copied: leonberger_105.jpg to ../training_val
# Copied: leonberger_106.jpg to ../training_val
# Copied: leonberger_107.jpg to ../training_val
# Copied: leonberger_108.jpg to ../training_val
# Copied: leonberger_109.jpg to ../training_val
# Copied: leonberger_10.jpg to ../training_val
# Copied: leonberger_110.jpg to ../training_val
# Copied: leonberger_111.jpg to ../training_val
# Copied: leonberger_112.jpg to ../training_val
# Copied: leonberger_113.jpg to ../training_val
# Copied: leonberger_114.jpg to ../training_val
# Copied: leonberger_115.jpg to ../training_val
# Copied: leonberger_116.jpg to ../training_val
# Copied: leonberger_117.jpg to ../training_val
# Copied: leonberger_118.jpg to ../training_val
# Copied: leonberger_119.jpg to ../training_val
# Copied: leonberger_11.jpg to ../training_val
# Copied: leonberger_120.jpg to ../training_val
# Copied: leonberger_121.jpg to ../training_val
# Copied: leonberger_122.jpg to ../training_val
# Copied: leonberger_123.jpg to ../training_val
# Copied: leonberger_124.jpg to ../training_val
# Copied: leonberger_125.jpg to ../training_val
# Copied: leonberger_126.jpg to ../training_val
# Copied: leonberger_127.jpg to ../training_val
# Copied: leonberger_128.jpg to ../training_val
# Copied: leonberger_129.jpg to ../training_val
# Copied: leonberger_12.jpg to ../training_val
# Copied: leonberger_130.jpg to ../training_val
# Copied: leonberger_131.jpg to ../training_val
# Copied: leonberger_132.jpg to ../training_val
# Copied: leonberger_133.jpg to ../training_val
# Copied: leonberger_134.jpg to ../training_val
# Copied: leonberger_135.jpg to ../training_val
# Copied: leonberger_136.jpg to ../training_val
# Copied: leonberger_137.jpg to ../training_val
# Copied: leonberger_138.jpg to ../training_val
# Copied: leonberger_139.jpg to ../training_val
# Copied: leonberger_13.jpg to ../training_val
# Copied: leonberger_140.jpg to ../training_val
# Copied: leonberger_141.jpg to ../training_val
# Copied: leonberger_142.jpg to ../training_val
# Copied: leonberger_143.jpg to ../training_val
# Copied: leonberger_144.jpg to ../training_val
# Copied: leonberger_145.jpg to ../training_val
# Copied: Maine_Coon_100.jpg to ../training_val
# Copied: Maine_Coon_101.jpg to ../training_val
# Copied: Maine_Coon_102.jpg to ../training_val
# Copied: Maine_Coon_103.jpg to ../training_val
# Copied: Maine_Coon_104.jpg to ../training_val
# Copied: Maine_Coon_105.jpg to ../training_val
# Copied: Maine_Coon_106.jpg to ../training_val
# Copied: Maine_Coon_107.jpg to ../training_val
# ...
# Copied: scottish_terrier_16.jpg to ../training_val
# Copied: scottish_terrier_170.jpg to ../training_val
# Copied: scottish_terrier_171.jpg to ../training_val
# Copied: scottish_terrier_172.jpg to ../training_val
# Copied: scottish_terrier_173.jpg to ../training_val
# Copied: scottish_terrier_174.jpg to ../training_val
# Copied: scottish_terrier_175.jpg to ../training_val
# Copied: scottish_terrier_176.jpg to ../training_val
# Copied: scottish_terrier_177.jpg to ../training_val
# Copied: scottish_terrier_178.jpg to ../training_val
# Copied: scottish_terrier_179.jpg to ../training_val
# Copied: scottish_terrier_17.jpg to ../training_val
# Copied: scottish_terrier_180.jpg to ../training_val
# Copied: scottish_terrier_181.jpg to ../training_val
# Copied: scottish_terrier_182.jpg to ../training_val
# Copied: scottish_terrier_183.jpg to ../training_val
# Copied: scottish_terrier_184.jpg to ../training_val
# Copied: scottish_terrier_185.jpg to ../training_val
# Copied: scottish_terrier_186.jpg to ../training_val
# Copied: scottish_terrier_187.jpg to ../training_val
# Copied: scottish_terrier_188.jpg to ../training_val
# Copied: scottish_terrier_189.jpg to ../training_val
# Copied: scottish_terrier_18.jpg to ../training_val
# Copied: scottish_terrier_190.jpg to ../training_val
# Copied: shiba_inu_147.jpg to ../training_val
# Copied: shiba_inu_14.jpg to ../training_val
# Copied: shiba_inu_150.jpg to ../training_val
# Copied: shiba_inu_152.jpg to ../training_val
# Copied: shiba_inu_153.jpg to ../training_val
# Copied: shiba_inu_154.jpg to ../training_val
# Copied: shiba_inu_155.jpg to ../training_val
# Copied: shiba_inu_156.jpg to ../training_val
# Copied: shiba_inu_157.jpg to ../training_val
# Copied: shiba_inu_158.jpg to ../training_val
# Copied: shiba_inu_159.jpg to ../training_val
# Copied: shiba_inu_15.jpg to ../training_val
# Copied: shiba_inu_160.jpg to ../training_val
# Copied: shiba_inu_161.jpg to ../training_val
# Copied: shiba_inu_162.jpg to ../training_val
# Copied: shiba_inu_163.jpg to ../training_val
# Copied: shiba_inu_164.jpg to ../training_val
# Copied: shiba_inu_165.jpg to ../training_val
# Copied: shiba_inu_166.jpg to ../training_val
# Copied: shiba_inu_168.jpg to ../training_val
# Copied: shiba_inu_16.jpg to ../training_val
# Copied: shiba_inu_170.jpg to ../training_val
# Copied: shiba_inu_171.jpg to ../training_val
# Copied: shiba_inu_172.jpg to ../training_val
# Copied: shiba_inu_173.jpg to ../training_val
# Copied: shiba_inu_174.jpg to ../training_val
# Copied: shiba_inu_175.jpg to ../training_val
# Copied: shiba_inu_176.jpg to ../training_val
# Copied: shiba_inu_177.jpg to ../training_val
# Copied: shiba_inu_178.jpg to ../training_val
# Copied: shiba_inu_179.jpg to ../training_val
# Copied: shiba_inu_180.jpg to ../training_val
# Copied: shiba_inu_181.jpg to ../training_val
# Copied: shiba_inu_182.jpg to ../training_val
# Copied: shiba_inu_183.jpg to ../training_val
# Copied: shiba_inu_185.jpg to ../training_val
# Copied: shiba_inu_186.jpg to ../training_val
# Copied: shiba_inu_187.jpg to ../training_val
# Copied: shiba_inu_189.jpg to ../training_val
# Copied: shiba_inu_18.jpg to ../training_val
# Copied: shiba_inu_190.jpg to ../training_val
# Copied: shiba_inu_191.jpg to ../training_val
# Copied: shiba_inu_192.jpg to ../training_val
# Copied: shiba_inu_193.jpg to ../training_val
# Copied: shiba_inu_194.jpg to ../training_val
# Copied: shiba_inu_195.jpg to ../training_val
# Copied: shiba_inu_196.jpg to ../training_val
# Copied: shiba_inu_198.jpg to ../training_val
# Copied: shiba_inu_199.jpg to ../training_val
# Copied: shiba_inu_19.jpg to ../training_val
# Copied: Siamese_157.jpg to ../training_val
# Copied: Siamese_158.jpg to ../training_val
# Copied: Siamese_159.jpg to ../training_val
# Copied: Siamese_160.jpg to ../training_val
# Copied: Siamese_161.jpg to ../training_val
# Copied: Siamese_162.jpg to ../training_val
# Copied: Siamese_163.jpg to ../training_val
# Copied: Siamese_164.jpg to ../training_val
# Copied: Siamese_165.jpg to ../training_val
# Copied: Siamese_167.jpg to ../training_val
# Copied: Siamese_168.jpg to ../training_val
# Copied: Siamese_169.jpg to ../training_val
# Copied: Siamese_170.jpg to ../training_val
# Copied: Siamese_171.jpg to ../training_val
# Copied: Siamese_172.jpg to ../training_val
# Copied: Siamese_173.jpg to ../training_val
# Copied: Siamese_174.jpg to ../training_val
# Copied: Siamese_175.jpg to ../training_val
# Copied: Siamese_176.jpg to ../training_val
# Copied: Siamese_178.jpg to ../training_val
# Copied: Siamese_179.jpg to ../training_val
# Copied: Siamese_17.jpg to ../training_val
# Copied: Siamese_180.jpg to ../training_val
# Copied: Siamese_181.jpg to ../training_val
# Copied: Siamese_182.jpg to ../training_val
# Copied: Siamese_183.jpg to ../training_val
# Copied: Siamese_184.jpg to ../training_val
# Copied: Siamese_185.jpg to ../training_val
# Copied: Siamese_186.jpg to ../training_val
# Copied: Siamese_187.jpg to ../training_val
# Copied: Siamese_188.jpg to ../training_val
# Copied: Siamese_189.jpg to ../training_val
# Copied: Siamese_18.jpg to ../training_val
# Copied: Siamese_191.jpg to ../training_val
# Copied: Siamese_193.jpg to ../training_val
# Copied: Siamese_194.jpg to ../training_val
# Copied: Siamese_195.jpg to ../training_val
# Copied: Siamese_196.jpg to ../training_val
# Copied: Siamese_198.jpg to ../training_val
# Copied: Siamese_199.jpg to ../training_val
# Copied: Siamese_19.jpg to ../training_val
# Copied: Siamese_200.jpg to ../training_val
# Copied: Siamese_201.jpg to ../training_val
# Copied: Siamese_202.jpg to ../training_val
# Copied: Siamese_204.jpg to ../training_val
# Copied: Siamese_205.jpg to ../training_val
# Copied: Siamese_206.jpg to ../training_val
# Copied: Siamese_207.jpg to ../training_val
# Copied: Siamese_208.jpg to ../training_val
# Copied: Sphynx_15.jpg to ../training_val
# Copied: Sphynx_160.jpg to ../training_val
# Copied: Sphynx_162.jpg to ../training_val
# Copied: Sphynx_164.jpg to ../training_val
# Copied: Sphynx_165.jpg to ../training_val
# Copied: Sphynx_166.jpg to ../training_val
# Copied: Sphynx_167.jpg to ../training_val
# Copied: Sphynx_168.jpg to ../training_val
# Copied: Sphynx_169.jpg to ../training_val
# Copied: Sphynx_170.jpg to ../training_val
# Copied: Sphynx_171.jpg to ../training_val
# Copied: Sphynx_172.jpg to ../training_val
# Copied: Sphynx_173.jpg to ../training_val
# Copied: Sphynx_174.jpg to ../training_val
# Copied: Sphynx_175.jpg to ../training_val
# Copied: Sphynx_176.jpg to ../training_val
# Copied: Sphynx_177.jpg to ../training_val
# Copied: Sphynx_178.jpg to ../training_val
# Copied: Sphynx_179.jpg to ../training_val
# Copied: Sphynx_17.jpg to ../training_val
# Copied: Sphynx_180.jpg to ../training_val
# Copied: Sphynx_181.jpg to ../training_val
# Copied: Sphynx_182.jpg to ../training_val
# Copied: Sphynx_183.jpg to ../training_val
# Copied: Sphynx_184.jpg to ../training_val
# Copied: Sphynx_185.jpg to ../training_val
# Copied: Sphynx_186.jpg to ../training_val
# Copied: Sphynx_187.jpg to ../training_val
# Copied: Sphynx_188.jpg to ../training_val
# Copied: Sphynx_189.jpg to ../training_val
# Copied: Sphynx_18.jpg to ../training_val
# Copied: Sphynx_190.jpg to ../training_val
# Copied: Sphynx_191.jpg to ../training_val
# Copied: Sphynx_192.jpg to ../training_val
# Copied: Sphynx_193.jpg to ../training_val
# Copied: Sphynx_194.jpg to ../training_val
# Copied: Sphynx_195.jpg to ../training_val
# Copied: Sphynx_196.jpg to ../training_val
# Copied: Sphynx_197.jpg to ../training_val
# Copied: Sphynx_198.jpg to ../training_val
# Copied: Sphynx_199.jpg to ../training_val
# Copied: Sphynx_19.jpg to ../training_val
# Copied: Sphynx_1.jpg to ../training_val
# Copied: Sphynx_200.jpg to ../training_val
# Copied: Sphynx_201.jpg to ../training_val
# Copied: Sphynx_202.jpg to ../training_val
# Copied: Sphynx_203.jpg to ../training_val
# Copied: Sphynx_204.jpg to ../training_val
# Copied: Sphynx_205.jpg to ../training_val
# Copied: Sphynx_206.jpg to ../training_val
# Copied: staffordshire_bull_terrier_149.jpg to ../training_val
# Copied: staffordshire_bull_terrier_14.jpg to ../training_val
# Copied: staffordshire_bull_terrier_150.jpg to ../training_val
# Copied: staffordshire_bull_terrier_151.jpg to ../training_val
# Copied: staffordshire_bull_terrier_152.jpg to ../training_val
# Copied: staffordshire_bull_terrier_154.jpg to ../training_val
# Copied: staffordshire_bull_terrier_155.jpg to ../training_val
# Copied: staffordshire_bull_terrier_156.jpg to ../training_val
# Copied: staffordshire_bull_terrier_158.jpg to ../training_val
# Copied: staffordshire_bull_terrier_159.jpg to ../training_val
# Copied: staffordshire_bull_terrier_15.jpg to ../training_val
# Copied: staffordshire_bull_terrier_160.jpg to ../training_val
# Copied: staffordshire_bull_terrier_162.jpg to ../training_val
# Copied: staffordshire_bull_terrier_163.jpg to ../training_val
# Copied: staffordshire_bull_terrier_165.jpg to ../training_val
# Copied: staffordshire_bull_terrier_166.jpg to ../training_val
# Copied: staffordshire_bull_terrier_167.jpg to ../training_val
# Copied: staffordshire_bull_terrier_168.jpg to ../training_val
# Copied: staffordshire_bull_terrier_169.jpg to ../training_val
# Copied: staffordshire_bull_terrier_16.jpg to ../training_val
# Copied: staffordshire_bull_terrier_170.jpg to ../training_val
# Copied: staffordshire_bull_terrier_171.jpg to ../training_val
# Copied: staffordshire_bull_terrier_172.jpg to ../training_val
# Copied: staffordshire_bull_terrier_173.jpg to ../training_val
# Copied: staffordshire_bull_terrier_174.jpg to ../training_val
# Copied: staffordshire_bull_terrier_175.jpg to ../training_val
# Copied: staffordshire_bull_terrier_176.jpg to ../training_val
# Copied: staffordshire_bull_terrier_177.jpg to ../training_val
# Copied: staffordshire_bull_terrier_179.jpg to ../training_val
# Copied: staffordshire_bull_terrier_17.jpg to ../training_val
# Copied: staffordshire_bull_terrier_180.jpg to ../training_val
# Copied: staffordshire_bull_terrier_181.jpg to ../training_val
# Copied: staffordshire_bull_terrier_183.jpg to ../training_val
# Copied: staffordshire_bull_terrier_184.jpg to ../training_val
# Copied: staffordshire_bull_terrier_185.jpg to ../training_val
# Copied: staffordshire_bull_terrier_186.jpg to ../training_val
# Copied: staffordshire_bull_terrier_188.jpg to ../training_val
# Copied: staffordshire_bull_terrier_189.jpg to ../training_val
# Copied: staffordshire_bull_terrier_18.jpg to ../training_val
# Copied: staffordshire_bull_terrier_190.jpg to ../training_val
# Copied: staffordshire_bull_terrier_191.jpg to ../training_val
# Copied: staffordshire_bull_terrier_192.jpg to ../training_val
# Copied: staffordshire_bull_terrier_194.jpg to ../training_val
# Copied: staffordshire_bull_terrier_195.jpg to ../training_val
# Copied: staffordshire_bull_terrier_196.jpg to ../training_val
# Copied: staffordshire_bull_terrier_197.jpg to ../training_val
# Copied: staffordshire_bull_terrier_198.jpg to ../training_val
# Copied: staffordshire_bull_terrier_199.jpg to ../training_val
# Copied: staffordshire_bull_terrier_19.jpg to ../training_val
# Copied: staffordshire_bull_terrier_1.jpg to ../training_val
# Copied: wheaten_terrier_146.jpg to ../training_val
# Copied: wheaten_terrier_147.jpg to ../training_val
# Copied: wheaten_terrier_148.jpg to ../training_val
# Copied: wheaten_terrier_149.jpg to ../training_val
# Copied: wheaten_terrier_14.jpg to ../training_val
# Copied: wheaten_terrier_150.jpg to ../training_val
# Copied: wheaten_terrier_151.jpg to ../training_val
# Copied: wheaten_terrier_152.jpg to ../training_val
# Copied: wheaten_terrier_153.jpg to ../training_val
# Copied: wheaten_terrier_154.jpg to ../training_val
# Copied: wheaten_terrier_155.jpg to ../training_val
# Copied: wheaten_terrier_156.jpg to ../training_val
# Copied: wheaten_terrier_157.jpg to ../training_val
# Copied: wheaten_terrier_158.jpg to ../training_val
# Copied: wheaten_terrier_159.jpg to ../training_val
# Copied: wheaten_terrier_15.jpg to ../training_val
# Copied: wheaten_terrier_160.jpg to ../training_val
# Copied: wheaten_terrier_161.jpg to ../training_val
# Copied: wheaten_terrier_162.jpg to ../training_val
# Copied: wheaten_terrier_163.jpg to ../training_val
# Copied: wheaten_terrier_164.jpg to ../training_val
# Copied: wheaten_terrier_165.jpg to ../training_val
# Copied: wheaten_terrier_166.jpg to ../training_val
# Copied: wheaten_terrier_167.jpg to ../training_val
# Copied: wheaten_terrier_168.jpg to ../training_val
# Copied: wheaten_terrier_169.jpg to ../training_val
# Copied: wheaten_terrier_16.jpg to ../training_val
# Copied: wheaten_terrier_170.jpg to ../training_val
# Copied: wheaten_terrier_171.jpg to ../training_val
# Copied: wheaten_terrier_172.jpg to ../training_val
# Copied: wheaten_terrier_173.jpg to ../training_val
# Copied: wheaten_terrier_174.jpg to ../training_val
# Copied: wheaten_terrier_175.jpg to ../training_val
# Copied: wheaten_terrier_176.jpg to ../training_val
# Copied: wheaten_terrier_177.jpg to ../training_val
# Copied: wheaten_terrier_178.jpg to ../training_val
# Copied: wheaten_terrier_179.jpg to ../training_val
# Copied: wheaten_terrier_17.jpg to ../training_val
# Copied: wheaten_terrier_180.jpg to ../training_val
# Copied: wheaten_terrier_181.jpg to ../training_val
# Copied: wheaten_terrier_182.jpg to ../training_val
# Copied: wheaten_terrier_183.jpg to ../training_val
# Copied: wheaten_terrier_184.jpg to ../training_val
# Copied: wheaten_terrier_185.jpg to ../training_val
# Copied: wheaten_terrier_186.jpg to ../training_val
# Copied: wheaten_terrier_187.jpg to ../training_val
# Copied: wheaten_terrier_188.jpg to ../training_val
# Copied: wheaten_terrier_189.jpg to ../training_val
# Copied: wheaten_terrier_18.jpg to ../training_val
# Copied: wheaten_terrier_190.jpg to ../training_val
# Copied: yorkshire_terrier_146.jpg to ../training_val
# Copied: yorkshire_terrier_147.jpg to ../training_val
# Copied: yorkshire_terrier_148.jpg to ../training_val
# Copied: yorkshire_terrier_149.jpg to ../training_val
# Copied: yorkshire_terrier_14.jpg to ../training_val
# Copied: yorkshire_terrier_150.jpg to ../training_val
# Copied: yorkshire_terrier_151.jpg to ../training_val
# Copied: yorkshire_terrier_152.jpg to ../training_val
# Copied: yorkshire_terrier_153.jpg to ../training_val
# Copied: yorkshire_terrier_154.jpg to ../training_val
# Copied: yorkshire_terrier_155.jpg to ../training_val
# Copied: yorkshire_terrier_156.jpg to ../training_val
# Copied: yorkshire_terrier_157.jpg to ../training_val
# Copied: yorkshire_terrier_158.jpg to ../training_val
# Copied: yorkshire_terrier_159.jpg to ../training_val
# Copied: yorkshire_terrier_15.jpg to ../training_val
# Copied: yorkshire_terrier_160.jpg to ../training_val
# Copied: yorkshire_terrier_161.jpg to ../training_val
# Copied: yorkshire_terrier_162.jpg to ../training_val
# Copied: yorkshire_terrier_163.jpg to ../training_val
# Copied: yorkshire_terrier_164.jpg to ../training_val
# Copied: yorkshire_terrier_165.jpg to ../training_val
# Copied: yorkshire_terrier_166.jpg to ../training_val
# Copied: yorkshire_terrier_167.jpg to ../training_val
# Copied: yorkshire_terrier_168.jpg to ../training_val
# Copied: yorkshire_terrier_169.jpg to ../training_val
# Copied: yorkshire_terrier_16.jpg to ../training_val
# Copied: yorkshire_terrier_170.jpg to ../training_val
# Copied: yorkshire_terrier_171.jpg to ../training_val
# Copied: yorkshire_terrier_172.jpg to ../training_val
# Copied: yorkshire_terrier_173.jpg to ../training_val
# Copied: yorkshire_terrier_174.jpg to ../training_val
# Copied: yorkshire_terrier_175.jpg to ../training_val
# Copied: yorkshire_terrier_176.jpg to ../training_val
# Copied: yorkshire_terrier_177.jpg to ../training_val
# Copied: yorkshire_terrier_178.jpg to ../training_val
# Copied: yorkshire_terrier_179.jpg to ../training_val
# Copied: yorkshire_terrier_17.jpg to ../training_val
# Copied: yorkshire_terrier_180.jpg to ../training_val
# Copied: yorkshire_terrier_181.jpg to ../training_val
# Copied: yorkshire_terrier_182.jpg to ../training_val
# Copied: yorkshire_terrier_183.jpg to ../training_val
# Copied: yorkshire_terrier_184.jpg to ../training_val
# Copied: yorkshire_terrier_185.jpg to ../training_val
# Copied: yorkshire_terrier_186.jpg to ../training_val
# Copied: yorkshire_terrier_187.jpg to ../training_val
# Copied: yorkshire_terrier_188.jpg to ../training_val
# Copied: yorkshire_terrier_189.jpg to ../training_val
# Copied: yorkshire_terrier_18.jpg to ../training_val
# Copied: yorkshire_terrier_190.jpg to ../training_val
